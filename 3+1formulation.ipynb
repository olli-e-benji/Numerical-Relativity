# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.axhline(4, c='green')
plt.axhline(3, c='green')
plt.axhline(2, c='green')
plt.axhline(1, c='green')
plt.axhline(0.5, c='green')
plt.axhline(3.5, c='green')
plt.axhline(2.5, c='green')
plt.axhline(1.5, c='green')
plt.axhline(0.5, c='green')
plt.arrow(x=0.8, y=2, dx=0, dy=0.3, head_width=0.10, head_length=0.2, color='royalblue', linewidth=2, label='n')
plt.arrow(x=3, y=1, dx=0, dy=0.3, head_width=0.10, head_length=0.2, color='royalblue', linewidth=2, label='n')
plt.arrow(x=3.8, y=0.5, dx=0, dy=0.3, head_width=0.10, head_length=0.2, color='royalblue', linewidth=2, label='n')
plt.arrow(x=1.5, y=2.5, dx=0, dy=0.3, head_width=0.10, head_length=0.2, color='royalblue', linewidth=2, label='n')
plt.arrow(x=0.2, y=3.5, dx=0, dy=0.3, head_width=0.10, head_length=0.2, color='royalblue', linewidth=2, label='n')
plt.arrow(x=2, y=3, dx=0, dy=0.3, head_width=0.10, head_length=0.2, color='royalblue', linewidth=2, label='n')
plt.arrow(x=2.5, y=1.5, dx=0, dy=0.3, head_width=0.10, head_length=0.2, color='royalblue', linewidth=2, label='n')


plt.xlim(0, 4)
plt.xlabel('x')
plt.ylabel('t')

plt.savefig('3+1.png', dpi=400)
